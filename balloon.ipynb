# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score

# %% [markdown]
# # Balloon radiation dataset

# %%
# http://lib.stat.cmu.edu/datasets/balloon

# %% [markdown]
# height and radiation

# %%
features = ['Height', 
'Radiation (???)']

# %%
df = pd.read_csv('./balloon_data.csv', header=None, names=features, delimiter=r"\s+")

# %%
print(df.shape)
df.head()
# Out:
# (2001, 2)
#    Height  Radiation (???)
# 0    1.76             0.00
# 1    1.76             0.00
# 2    1.76             0.00
# 3    1.76             0.00
# 4    1.74            -0.02

# %%
pd.plotting.scatter_matrix(df, figsize=(9,9), hist_kwds={'bins':50});
