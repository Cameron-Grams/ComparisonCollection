# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score

# %% [markdown]
# # Body Fat dataset

# %%
# http://lib.stat.cmu.edu/datasets/bodyfat

# %% [markdown]
# - Density determined from underwater weighing
# - Percent body fat from Siri's (1956) equation
# - Age (years)
# - Weight (lbs)
# - Height (inches)
# - Neck circumference (cm)
# - Chest circumference (cm)
# - Abdomen 2 circumference (cm)
# - Hip circumference (cm)
# - Thigh circumference (cm)
# - Knee circumference (cm)
# - Ankle circumference (cm)
# - Biceps (extended) circumference (cm)
# - Forearm circumference (cm)
# - Wrist circumference (cm)

# %%
features = ['Density', 
'Percent body fat', 
'Age', 
'Weight',
'Height', 
'Neck circumference',
'Chest circumference',
'Abdomen 2 circumference',
'Hip circumference',
'Thigh circumference',
'Knee circumference',
'Ankle circumference',
'Biceps (extended) circumference',
'Forearm circumference',
'Wrist circumference']

# %%
df = pd.read_csv('./bodyfat_data.csv', header=None, names=features, delimiter=r"\s+")

# %%
print(df.shape)
df.head()
# Out:
# (252, 15)
#    Density  Percent body fat  Age  Weight  Height  Neck circumference  \
# 0   1.0708              12.3   23  154.25   67.75                36.2
# 1   1.0853               6.1   22  173.25   72.25                38.5
# 2   1.0414              25.3   22  154.00   66.25                34.0
# 3   1.0751              10.4   26  184.75   72.25                37.4
# 4   1.0340              28.7   24  184.25   71.25                34.4
#
#    Chest circumference  Abdomen 2 circumference  Hip circumference  \
# 0                 93.1                     85.2               94.5
# 1                 93.6                     83.0               98.7
# 2                 95.8                     87.9               99.2
# 3                101.8                     86.4              101.2
# 4                 97.3                    100.0              101.9
#
#    Thigh circumference  Knee circumference  Ankle circumference  \
# ...

# %%
pd.plotting.scatter_matrix(df, figsize=(15, 15), hist_kwds={'bins':50});
