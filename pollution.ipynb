# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score

# %% [markdown]
# # Balloon radiation dataset

# %%
# http://lib.stat.cmu.edu/datasets/balloon

# %% [markdown]
# height and radiation

# %%
features = [
'concentration PM10',
'cars per hour',
'temp C',
'wind speed',
'temp diff 2 & 25m',
'wind direction (0-360)',
'hour of day', 
'day number'
]

# %%
df = pd.read_csv('./pollution.csv', header=None, names=features, delimiter=r"\s+")

# %%
print(df.shape)
df.head()
# Out:
# (500, 8)
#    concentration PM10  cars per hour  temp C  wind speed  temp diff 2 & 25m  \
# 0             3.66356        7.74414    -4.4         4.2                0.0
# 1             3.04452        8.03398    -5.7         4.8               -0.3
# 2             3.71357        4.70048   -13.5         4.3                0.2
# 3             2.94444        7.52510     1.4         3.0                0.1
# 4             4.06044        7.76260     4.1         5.6                1.1
#
#    wind direction (0-360)  hour of day  day number
# 0                    18.0           19         116
# 1                    69.1            9         506
# 2                    80.0            3          95
# 3                   177.0           22         161
# 4                   287.0            7          80

# %%
pd.plotting.scatter_matrix(df, figsize=(15, 15), hist_kwds={'bins':50});
