# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import precision_recall_curve, roc_curve, roc_auc_score

from sklearn.model_selection import cross_validate, KFold

# %%
np.random.seed(0)

# %% [markdown]
# ## Assessment of the intial RandomForestClassifier

# %%
def classifier_assessment(X, y):
    """
    RandomForestClassifier comparison for the different datasets

    args: X dataset of features
          y target set of values for classification

    returns: 
        - a dummy classifier score using "most frequent" value assignment
        - the mean of the RandomForest Claffifier prediction scores taken from a 
          5 fold cross validation on the dataset
        - a dataframe that shows the 10 most important features used by the classifer          
    """
    
    clf_rf = RandomForestClassifier(max_depth=4, random_state=0)
    
    def performance_graphics(X=X, y=y, clf_rf=clf_rf):
        # type of certainty tied to classifier passed in
        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
        clf_rf.fit(X_train, y_train)
     
        rf_proba = clf_rf.predict_proba(X_test)[:, 1]

        precision, recall, thresholds = precision_recall_curve(y_test, rf_proba)
        fp, tp, thresholds_roc = roc_curve(y_test, rf_proba)
        
        auc_score = np.round(roc_auc_score(y_test, rf_proba), 4)

        close_default = np.argmin(np.abs(thresholds - 0.5))
        close_zero = np.argmin(np.abs(thresholds_roc))

        fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15, 4))

        ax1.plot(precision, recall, label="Precision Recall Curve")
        ax1.plot(precision[close_default], 
                 recall[close_default], 'o', 
                 c='r', markersize=10, 
                 label='threshold 0.5', 
                 fillstyle="none", mew=2)
        ax1.set_title("RF performance")
        ax1.set_xlabel("Precision")
        ax1.set_ylabel("Recall")
        ax1.legend(loc='best')

        ax2.plot(fp, tp, label="ROC curve")
        ax2.plot(fp[close_zero], 
                 tp[close_zero], 'o', 
                 c='r', markersize=10, 
                 label='threshold 0', 
                 fillstyle="none", mew=2)
        ax2.set_title(f"ROC performance: AUC Score {auc_score}")
        ax2.set_xlabel("False Positive Rate")
        ax2.set_ylabel("True Positive (Recall)")
        ax2.legend(loc='best')

        plt.show();



    clf_rf = RandomForestClassifier(max_depth=4, random_state=0)

    kfold = KFold(n_splits=5)
    cross_val = cross_validate(clf_rf, X, y, cv=kfold, return_estimator=True)
    mean_score = cross_val['test_score'].mean()

    estimator = cross_val['estimator']
    ranked_features = {}

    for i, clf in enumerate(estimator):
        clf_no = i + 1
        feat_imp_val = clf.feature_importances_
        cols = X.columns
        feature_importance = list(zip(cols, feat_imp_val))
        feature_importance = sorted(feature_importance, key=lambda x: x[1], reverse=True)
        feature_importance = [ f[0] for f in feature_importance]
        ranked_features[f"Estimator: {clf_no}"] = feature_importance[:10]
        
    dummy_clf = DummyClassifier(strategy="most_frequent")
    dummy_clf.fit(X,y)
    d_score = dummy_clf.score(X,y)
    
    df = pd.DataFrame(ranked_features)

    graphic = performance_graphics

    return d_score, mean_score, df, graphic

# %% [markdown]
# # Compare Datasets
#
# Leave commented until the notebook has placed the values in scope.  Then uncomment to view the comparisons.

# %%
# # # # # # # # The results of the combinations: 

# obj_ = [('testing dataset', dummy_single,  single_score, (83, 2)), 
#        ('testing and acs datasets', dummy_double, score_two_datasets, (83, 119)),\
#        ]

# condition = [c[0] for c in obj_]
# dummy_results = [d[1] for d in obj_]
# results = [r[2] for r in obj_]
# shape = [s[3] for s in obj_]

# pd.DataFrame({'dummy classifier': dummy_results, 'cross val score': results, 'data set shape': shape}, index=condition)

# %%
# df_single_set_output
# df_two_datasets_output

# %%
# graphic_single()
# graphic_two()

# %% [markdown]
# ## Initial testing dataset of blood lead levels

# %%
# dataset prepared with this notebook: 
# https://github.com/Cameron-Grams/ComparisonCollection/blob/main/ebll_exploration.ipynb

df_ebll = pd.read_csv('./data/ebll_classifier_2014.csv')

# %%
# standardize the county names

df_ebll = df_ebll.iloc[:83, :]
df_ebll['county'] = df_ebll['County Name'].apply(lambda x: x.split()[:-1])
df_ebll['county'] = df_ebll['county'].apply(lambda x: (' ').join(x).lower())
# df_ebll.tail(30)

# %%
df_ebll = df_ebll.set_index('county')
df_ebll = df_ebll.iloc[:, 2:]
starting_df = df_ebll.iloc[:, :-1]
starting_df = starting_df.reset_index()
target = df_ebll.iloc[:, -1]

# %%
# starting_df.head()

# %% [markdown]
# ### Assess single dataset

# %%
df_single_set = starting_df.set_index('county')
X = df_single_set
y = target
X.shape
# Out:
# (83, 2)

# %%
dummy_single, single_score, df_single_set_output, graphic_single = classifier_assessment(X, y)
dummy_single, single_score
# Out:
# (0.7349397590361446, 0.8433823529411765)

# %%
df_single_set_output
# Out:
#                                       Estimator: 1  \
# 0     Number of Children Tested < 72 Months of Age
# 1  Total Population of Children < 72 Months of Age
#
#                                       Estimator: 2  \
# 0     Number of Children Tested < 72 Months of Age
# 1  Total Population of Children < 72 Months of Age
#
#                                       Estimator: 3  \
# 0     Number of Children Tested < 72 Months of Age
# 1  Total Population of Children < 72 Months of Age
#
#                                       Estimator: 4  \
# 0     Number of Children Tested < 72 Months of Age
# 1  Total Population of Children < 72 Months of Age
#
#                                       Estimator: 5
# 0     Number of Children Tested < 72 Months of Age
# 1  Total Population of Children < 72 Months of Age

# %%
# graphic_single()

# %% [markdown]
# ## Add American Community Survey dataset

# %%
# dataset prepared with this notebook:
# https://github.com/Cameron-Grams/ComparisonCollection/blob/main/acs_2014.ipynb

df_acs = pd.read_csv('./data/cleaned_2014_acs.csv')

# %%
df_acs.head()
# Out:
#       County Name Population 16 years and over In labor force  \
# 0   Alcona County                        9,424          3,796
# 1    Alger County                        8,221          3,602
# 2  Allegan County                       87,238         54,617
# 3   Alpena County                       24,077         13,731
# 4   Antrim County                       19,340         10,762
#
#   Civilian labor force Employed Unemployed Armed Forces Not in labor force  \
# 0                3,796    3,294        502            0              5,628
# 1                3,602    3,175        427            0              4,619
# 2               54,614   50,406      4,208            3             32,621
# 3               13,659   12,227      1,432           72             10,346
# 4               10,759    9,462      1,297            3              8,578
#
#   Civilian labor force.1 Females 16 years and over  ... Unemployed:  \
# 0                  3,796                     4,668  ...         478
# 1                  3,602                     3,618  ...         394
# 2                 54,614                    44,131  ...       3,868
# 3                 13,659                    12,369  ...       1,333
# 4                 10,759                     9,760  ...       1,148
#
#   With health insurance coverage.2 With private health insurance.2  \
# 0                              290                             177
# 1                              226                             110
# 2                            2,105                           1,432
# 3                              736                             351
# 4                              583                             388
#
#   With public coverage.2 No health insurance coverage.3 Not in labor force:  \
# 0                    128                            188               2,168
# 1                    118                            168               1,589
# 2                    761                          1,763              15,925
# 3                    425                            597               4,421
# 4                    208                            565               3,190
#
#   With health insurance coverage.3 With private health insurance.3  \
# 0                            1,849                           1,168
# 1                            1,364                             992
# 2                           13,143                           8,706
# 3                            3,890                           2,051
# 4                            2,716                           1,886
#
#   With public coverage.3 No health insurance coverage.4
# 0                    988                            319
# 1                    548                            225
# 2                  5,896                          2,782
# 3                  2,344                            531
# 4                  1,103                            474
#
# [5 rows x 118 columns]

# %%
# format county names
county = df_acs['County Name'].apply(lambda x: x.split()[:-1])
county = [(' ').join(x).lower() for x in county][:-1]

# %%
# need to replace the strings with integers
# get columns needed for conversion 
cols = df_acs.columns[1:]
df_acs_1 = df_acs.iloc[:, 1:]

# %%
# df contains a mixed collection of strings and numbers 
string_values = df_acs_1.values

# %%
new_vals = []
for arr in string_values:
    arr_2 = [x if (type(x) == int or type(x) == float) else int(x.replace(',', '')) for x in arr]
    new_vals.append(arr_2)

# %%
# last sample is the summary for Michigan as a state
number_array = np.array(new_vals)[:-1]

# %%
df_acs_2 = pd.DataFrame(number_array, columns=cols)

# %%
df_acs_2['county'] = county
df_acs_2.head()
# Out:
#    Population 16 years and over  In labor force  Civilian labor force  \
# 0                        9424.0          3796.0                3796.0
# 1                        8221.0          3602.0                3602.0
# 2                       87238.0         54617.0               54614.0
# 3                       24077.0         13731.0               13659.0
# 4                       19340.0         10762.0               10759.0
#
#    Employed  Unemployed  Armed Forces  Not in labor force  \
# 0    3294.0       502.0           0.0              5628.0
# 1    3175.0       427.0           0.0              4619.0
# 2   50406.0      4208.0           3.0             32621.0
# 3   12227.0      1432.0          72.0             10346.0
# 4    9462.0      1297.0           3.0              8578.0
#
#    Civilian labor force.1  Females 16 years and over  In labor force.1  ...  \
# 0                  3796.0                     4668.0            1830.0  ...
# 1                  3602.0                     3618.0            1720.0  ...
# 2                 54614.0                    44131.0           25248.0  ...
# 3                 13659.0                    12369.0            6583.0  ...
# 4                 10759.0                     9760.0            5076.0  ...
#
#    With health insurance coverage.2  With private health insurance.2  \
# 0                             290.0                            177.0
# 1                             226.0                            110.0
# 2                            2105.0                           1432.0
# 3                             736.0                            351.0
# 4                             583.0                            388.0
#
#    With public coverage.2  No health insurance coverage.3  \
# 0                   128.0                           188.0
# 1                   118.0                           168.0
# 2                   761.0                          1763.0
# 3                   425.0                           597.0
# 4                   208.0                           565.0
#
#    Not in labor force:  With health insurance coverage.3  \
# 0               2168.0                            1849.0
# 1               1589.0                            1364.0
# 2              15925.0                           13143.0
# 3               4421.0                            3890.0
# 4               3190.0                            2716.0
#
#    With private health insurance.3  With public coverage.3  \
# 0                           1168.0                   988.0
# 1                            992.0                   548.0
# 2                           8706.0                  5896.0
# 3                           2051.0                  2344.0
# 4                           1886.0                  1103.0
#
#    No health insurance coverage.4   county
# 0                           319.0   alcona
# 1                           225.0    alger
# 2                          2782.0  allegan
# 3                           531.0   alpena
# 4                           474.0   antrim
#
# [5 rows x 118 columns]

# %%
df_two_datasets_ = pd.merge(starting_df, df_acs_2, on='county')
df_two_datasets = df_two_datasets_.set_index('county')
df_two_datasets.shape
# Out:
# (83, 119)

# %%
X = df_two_datasets
y = target

# %%
dummy_double, score_two_datasets, df_two_datasets_output, graphic_two = classifier_assessment(X, y)
dummy_double, score_two_datasets
# Out:
# (0.7349397590361446, 0.8911764705882353)

# %%
# graphic_two()

# %%
df_two_datasets_output
# Out:
#                                         Estimator: 1  \
# 0                                             Walked
# 1      Transportation and warehousing, and utilities
# 2  Educational services, and health care and soci...
# 3                              Public administration
# 4                  With Supplemental Security Income
# 5                                 Government workers
# 6                                         Employed.1
# 7                                    Wholesale trade
# 8  With Food Stamp/SNAP benefits in the past 12 m...
# 9                                Less than $10,000.1
#
#                                         Estimator: 2  \
# 0                                 $10,000 to $14,999
# 1                              Public administration
# 2      Transportation and warehousing, and utilities
# 3  With Food Stamp/SNAP benefits in the past 12 m...
# 4                                Less than $10,000.1
# 5  Natural resources, construction, and maintenan...
# 6                                  Less than $10,000
# 7                     No health insurance coverage.2
# 8                 With cash public assistance income
# 9                               Nonfamily households
#
#                                         Estimator: 3  \
# 0  Educational services, and health care and soci...
# 1                                 Government workers
# 2  With Food Stamp/SNAP benefits in the past 12 m...
# 3                    With private health insurance.3
# 4      Transportation and warehousing, and utilities
# 5                                             Walked
# 6                              Public administration
# 7   Civilian employed population 16 years and over.2
# 8                                 $25,000 to $34,999
# 9                                Less than $10,000.1
#
#                                         Estimator: 4  \
# 0      Transportation and warehousing, and utilities
# 1                             With public coverage.1
# 2                               $10,000 to $14,999.1
# 3  With Food Stamp/SNAP benefits in the past 12 m...
# 4  Educational services, and health care and soci...
# 5                                Less than $10,000.1
# 6                                             Walked
# 7                              Public administration
# 8                  With Supplemental Security Income
# 9                                 $10,000 to $14,999
#
#                                         Estimator: 5
# 0                                             Walked
# 1  With Food Stamp/SNAP benefits in the past 12 m...
# 2                               $10,000 to $14,999.1
# 3                             With public coverage.1
# 4  Educational services, and health care and soci...
# 5                     No health insurance coverage.3
# 6      Transportation and warehousing, and utilities
# 7                                  Less than $10,000
# 8                                 $15,000 to $24,999
# 9                                Less than $10,000.1

# %%
two_ds_key_values = df_two_datasets_output.values
two_ds_key_features = set(two_ds_key_values.flatten())
# two_ds_key_features
